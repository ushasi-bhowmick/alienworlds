# %%
#here's my attempt at writing a different NN to tackle my problem... this is an inception network. lets see if it works
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix

# %%
IMG_SIZE=500

# %%
#some errors in this class thing so we'll see later....
class InceptionTime(keras.layers.Layer):
    def __init__(self, num_filters=32, activation='relu', **kwargs):
        super().__init__(**kwargs)
        self.num_filters=num_filters
        self.activation=keras.activations.get(activation)
        #self.conv1=keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")
        #self.conv1_2=keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")
        #self.conv10=keras.layers.Conv1D(filters=8, kernel_size=10, padding="same", strides=1, activation="tanh")
        #self.conv20=keras.layers.Conv1D(filters=8, kernel_size=20, padding="same", strides=1, activation="tanh")
        #self.conv40=keras.layers.Conv1D(filters=8, kernel_size=40, padding="same", strides=1, activation="tanh")

    def call(self, inputs,training=None):
        bN = keras.layers.Conv1D(filters=self.num_filters, kernel_size=1, padding="same", strides=1, activation="tanh")(inputs)
        mP = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(inputs)
        z1 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=3, padding="same", strides=1, activation="tanh")(bN)
        z2 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=7, padding="same", strides=1, activation="tanh")(bN)
        z3 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=11, padding="same", strides=1, activation="tanh")(bN)
        z4 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=1, padding="same", strides=1, activation="tanh")(mP)
        z = keras.layers.Concatenate(axis=2)([z1,z2,z3,z4])
        z = keras.layers.BatchNormalization()(z)
        return self.activation(z)

# %%
ip = keras.layers.Input(shape=(IMG_SIZE,1),name='Input')
x = keras.layers.Reshape((IMG_SIZE, 1), input_shape=(IMG_SIZE,),name='reshape_1')(ip)
x = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", strides=1, activation="tanh")(x)

y = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=2, activation="tanh",name='bypass')(x)
y = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=2, activation="relu",name='bypass2')(y)
y = keras.layers.BatchNormalization()(y)

bN1 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(x)
bN2 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(x)
bN3 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(x)
mP = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(x)
z1 = keras.layers.Conv1D(filters=8, kernel_size=5, padding="same", strides=1, activation="tanh")(bN1)
z2 = keras.layers.Conv1D(filters=8, kernel_size=15, padding="same", strides=1, activation="tanh")(bN2)
z3 = keras.layers.Conv1D(filters=8, kernel_size=35, padding="same", strides=1, activation="tanh")(bN3)
z4 = keras.layers.Conv1D(filters=4, kernel_size=1, padding="same", strides=1, activation="tanh")(mP)
z = keras.layers.Concatenate(axis=2)([z1,z2,z3,z4])
z = keras.layers.BatchNormalization()(z)

z  = keras.layers.AveragePooling1D(3,strides=2,padding='same')(z)

bNI1 = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(z)
bNI2 = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(z)
bNI3 = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(z)
mPI = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(z)
zI1 = keras.layers.Conv1D(filters=16, kernel_size=5, padding="same", strides=1, activation="tanh")(bNI1)
zI2 = keras.layers.Conv1D(filters=16, kernel_size=15, padding="same", strides=1, activation="tanh")(bNI2)
zI3 = keras.layers.Conv1D(filters=16, kernel_size=35, padding="same", strides=1, activation="tanh")(bNI3)
zI4 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(mPI)
zI = keras.layers.Concatenate(axis=2)([zI1,zI2,zI3,zI4])
zI = keras.layers.BatchNormalization()(zI)

zI  = keras.layers.AveragePooling1D(3,strides=2,padding='same')(zI)

bNII1 = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=1, activation="tanh")(zI)
bNII2 = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=1, activation="tanh")(zI)
bNII3 = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=1, activation="tanh")(zI)
mPII = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(zI)
z1II = keras.layers.Conv1D(filters=32, kernel_size=5, padding="same", strides=1, activation="tanh")(bNII1)
z2II = keras.layers.Conv1D(filters=32, kernel_size=15, padding="same", strides=1, activation="tanh")(bNII2)
z3II = keras.layers.Conv1D(filters=32, kernel_size=35, padding="same", strides=1, activation="tanh")(bNII3)
z4II = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(mPII)
zII = keras.layers.Concatenate(axis=2,name='bypassed_here')([z1II,z2II,z3II,z4II,y])
zII = keras.layers.BatchNormalization()(zII)

zII  = keras.layers.AveragePooling1D(3,strides=1,padding='same')(zII)

zII = keras.layers.Flatten()(zII)
zII = keras.layers.Dense(128,activation='relu')(zII)
zII = keras.layers.Dense(64,activation='relu')(zII)
#zII =  keras.layers.Dense(1,activation='relu')(zII)
zII =  keras.layers.Dense(3,activation='softmax')(zII)

NN = keras.Model(inputs=ip, outputs=zII ,name='Convolutional_NN')
NN.summary()


lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=0.00005,decay_steps=500,decay_rate=0.5)
NN.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule), loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Model: "Convolutional_NN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 500, 1)]     0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 500, 1)       0           Input[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 500, 64)      256         reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 500, 8)       520         conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 500, 8)       520         conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 500, 8)       520         conv1d_44[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 500, 64)      0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 500, 8)       328         conv1d_45[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 500, 8)       968         conv1d_46[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 500, 8)       2248        conv1d_47[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 500, 4)       260         max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 500, 28)      0           conv1d_48[0][0]
#                                                                  conv1d_49[0][0]
#                                                                  conv1d_50[0][0]
#                                                                  conv1d_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 500, 28)      112         concatenate_4[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_5 (AveragePoo (None, 250, 28)      0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 250, 16)      464         average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 250, 16)      464         average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 250, 16)      464         average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 250, 28)      0           average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 250, 16)      1296        conv1d_52[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 250, 16)      3856        conv1d_53[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 250, 16)      8976        conv1d_54[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 250, 8)       232         max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 250, 56)      0           conv1d_55[0][0]
#                                                                  conv1d_56[0][0]
#                                                                  conv1d_57[0][0]
#                                                                  conv1d_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 250, 56)      224         concatenate_5[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_6 (AveragePoo (None, 125, 56)      0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# bypass (Conv1D)                 (None, 250, 32)      2080        conv1d_44[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 125, 32)      1824        average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 125, 32)      1824        average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 125, 32)      1824        average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 125, 56)      0           average_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# bypass2 (Conv1D)                (None, 125, 32)      1056        bypass[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 125, 32)      5152        conv1d_59[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 125, 32)      15392       conv1d_60[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 125, 32)      35872       conv1d_61[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 125, 16)      912         max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 125, 32)      128         bypass2[0][0]
# __________________________________________________________________________________________________
# bypassed_here (Concatenate)     (None, 125, 144)     0           conv1d_62[0][0]
#                                                                  conv1d_63[0][0]
#                                                                  conv1d_64[0][0]
#                                                                  conv1d_65[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 125, 144)     576         bypassed_here[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_7 (AveragePoo (None, 125, 144)     0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 18000)        0           average_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          2304128     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3)            195         dense_4[0][0]
# ==================================================================================================
# Total params: 2,400,927
# Trainable params: 2,400,407
# Non-trainable params: 520
# __________________________________________________________________________________________________

# %%
# np.random.seed(123467)
X_train=np.loadtxt('training_data/Xtrain_rv_500_3_1o7.csv',delimiter=',')
Y_train=np.loadtxt('training_data/Ytrain_rv_500_3_1o7.csv',delimiter=',')
print(X_train.shape,Y_train.shape)
kernel_size = 3
kernel = np.ones(kernel_size) / kernel_size
X_train = np.array([np.convolve(X_train[i], kernel, mode='same') for i in range(len(X_train))])
#X_train=preprocessing.normalize(X_train)
#X_train=-X_train
#scalar=preprocessing.StandardScaler()
#scalar.fit(X_train)
#X_train=scalar.transform(X_train)

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X_train, Y_train, test_size=0.2)
print(Xtrain.shape,Xtest.shape)

vararr=np.random.randint(0,len(Xtrain),size=10)
fig,ax=plt.subplots(10,1,figsize=(10,20))
for i in range(0,10):
    ax[i].plot(Xtrain[vararr[i]])

plt.show
# Out:
# (6039, 500) (6039, 3)
# (4831, 500) (1208, 500)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
es_callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
#history=convNN.fit([np.array(Xtrain),np.array(Xtrainl)],np.array(Ytrain), batch_size=64, epochs=40, verbose=VERBOSE, validation_split=0.12,callbacks=[es_callback])
history=NN.fit(np.array(Xtrain),np.array(Ytrain), batch_size=64, epochs=50  , verbose=1 ,shuffle=True, validation_split=0.2)
# Out:
# Epoch 1/50
# 61/61 [==============================] - 30s 487ms/step - loss: 0.5473 - accuracy: 0.7875 - val_loss: 0.7246 - val_accuracy: 0.7063
# Epoch 2/50
# 61/61 [==============================] - 30s 486ms/step - loss: 0.5445 - accuracy: 0.7792 - val_loss: 0.7242 - val_accuracy: 0.7084
# Epoch 3/50
# 61/61 [==============================] - 30s 486ms/step - loss: 0.5443 - accuracy: 0.7808 - val_loss: 0.7251 - val_accuracy: 0.7001
# Epoch 4/50
# 61/61 [==============================] - 30s 492ms/step - loss: 0.5429 - accuracy: 0.7823 - val_loss: 0.7261 - val_accuracy: 0.7011
# Epoch 5/50
# 61/61 [==============================] - 30s 489ms/step - loss: 0.5447 - accuracy: 0.7821 - val_loss: 0.7249 - val_accuracy: 0.7022
# Epoch 6/50
# 61/61 [==============================] - 30s 488ms/step - loss: 0.5447 - accuracy: 0.7852 - val_loss: 0.7248 - val_accuracy: 0.7011
# Epoch 7/50
# 61/61 [==============================] - 31s 504ms/step - loss: 0.5435 - accuracy: 0.7842 - val_loss: 0.7247 - val_accuracy: 0.7084
# Epoch 8/50
# 61/61 [==============================] - 31s 504ms/step - loss: 0.5415 - accuracy: 0.7857 - val_loss: 0.7248 - val_accuracy: 0.7053
# Epoch 9/50
# 61/61 [==============================] - 32s 518ms/step - loss: 0.5430 - accuracy: 0.7852 - val_loss: 0.7247 - val_accuracy: 0.7053
# Epoch 10/50
# 61/61 [==============================] - 30s 495ms/step - loss: 0.5441 - accuracy: 0.7836 - val_loss: 0.7247 - val_accuracy: 0.7063
# Epoch 11/50
# 61/61 [==============================] - 30s 494ms/step - loss: 0.5421 - accuracy: 0.7847 - val_loss: 0.7253 - val_accuracy: 0.7011
# Epoch 12/50
# 61/61 [==============================] - 30s 491ms/step - loss: 0.5429 - accuracy: 0.7855 - val_loss: 0.7253 - val_accuracy: 0.7073
# Epoch 13/50
# 61/61 [==============================] - 30s 494ms/step - loss: 0.5400 - accuracy: 0.7883 - val_loss: 0.7248 - val_accuracy: 0.7104
# Epoch 14/50
# 61/61 [==============================] - 30s 493ms/step - loss: 0.5429 - accuracy: 0.7857 - val_loss: 0.7247 - val_accuracy: 0.7094
# Epoch 15/50
# 61/61 [==============================] - 30s 496ms/step - loss: 0.5401 - accuracy: 0.7875 - val_loss: 0.7249 - val_accuracy: 0.7063
# Epoch 16/50
# 61/61 [==============================] - 30s 493ms/step - loss: 0.5441 - accuracy: 0.7852 - val_loss: 0.7251 - val_accuracy: 0.7084
# Epoch 17/50
# 61/61 [==============================] - 30s 498ms/step - loss: 0.5413 - accuracy: 0.7867 - val_loss: 0.7251 - val_accuracy: 0.7063
# Epoch 18/50
# 61/61 [==============================] - 30s 494ms/step - loss: 0.5421 - accuracy: 0.7855 - val_loss: 0.7251 - val_accuracy: 0.7053
# Epoch 19/50
# 61/61 [==============================] - 30s 492ms/step - loss: 0.5423 - accuracy: 0.7865 - val_loss: 0.7251 - val_accuracy: 0.7073
# Epoch 20/50
# 61/61 [==============================] - 30s 489ms/step - loss: 0.5428 - accuracy: 0.7844 - val_loss: 0.7252 - val_accuracy: 0.7063
# Epoch 21/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5449 - accuracy: 0.7816 - val_loss: 0.7252 - val_accuracy: 0.7084
# Epoch 22/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5418 - accuracy: 0.7821 - val_loss: 0.7251 - val_accuracy: 0.7063
# Epoch 23/50
# 61/61 [==============================] - 26s 422ms/step - loss: 0.5430 - accuracy: 0.7857 - val_loss: 0.7253 - val_accuracy: 0.7042
# Epoch 24/50
# 61/61 [==============================] - 26s 425ms/step - loss: 0.5407 - accuracy: 0.7855 - val_loss: 0.7253 - val_accuracy: 0.7032
# Epoch 25/50
# 61/61 [==============================] - 26s 430ms/step - loss: 0.5420 - accuracy: 0.7805 - val_loss: 0.7253 - val_accuracy: 0.7073
# Epoch 26/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5421 - accuracy: 0.7870 - val_loss: 0.7253 - val_accuracy: 0.7042
# Epoch 27/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5394 - accuracy: 0.7852 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 28/50
# 61/61 [==============================] - 26s 431ms/step - loss: 0.5423 - accuracy: 0.7873 - val_loss: 0.7258 - val_accuracy: 0.7063
# Epoch 29/50
# 61/61 [==============================] - 26s 422ms/step - loss: 0.5412 - accuracy: 0.7821 - val_loss: 0.7258 - val_accuracy: 0.7042
# Epoch 30/50
# 61/61 [==============================] - 27s 437ms/step - loss: 0.5410 - accuracy: 0.7836 - val_loss: 0.7257 - val_accuracy: 0.7073
# Epoch 31/50
# 61/61 [==============================] - 26s 425ms/step - loss: 0.5398 - accuracy: 0.7880 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 32/50
# 61/61 [==============================] - 26s 423ms/step - loss: 0.5418 - accuracy: 0.7904 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 33/50
# 61/61 [==============================] - 26s 421ms/step - loss: 0.5422 - accuracy: 0.7829 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 34/50
# 61/61 [==============================] - 26s 420ms/step - loss: 0.5400 - accuracy: 0.7844 - val_loss: 0.7257 - val_accuracy: 0.7073
# Epoch 35/50
# 61/61 [==============================] - 26s 421ms/step - loss: 0.5401 - accuracy: 0.7873 - val_loss: 0.7258 - val_accuracy: 0.7063
# Epoch 36/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5440 - accuracy: 0.7865 - val_loss: 0.7257 - val_accuracy: 0.7042
# Epoch 37/50
# 61/61 [==============================] - 26s 425ms/step - loss: 0.5401 - accuracy: 0.7842 - val_loss: 0.7259 - val_accuracy: 0.7042
# Epoch 38/50
# 61/61 [==============================] - 26s 427ms/step - loss: 0.5399 - accuracy: 0.7842 - val_loss: 0.7257 - val_accuracy: 0.7042
# Epoch 39/50
# 61/61 [==============================] - 26s 425ms/step - loss: 0.5427 - accuracy: 0.7878 - val_loss: 0.7258 - val_accuracy: 0.7042
# Epoch 40/50
# 61/61 [==============================] - 26s 422ms/step - loss: 0.5427 - accuracy: 0.7836 - val_loss: 0.7258 - val_accuracy: 0.7042
# Epoch 41/50
# 61/61 [==============================] - 26s 423ms/step - loss: 0.5409 - accuracy: 0.7875 - val_loss: 0.7256 - val_accuracy: 0.7063
# Epoch 42/50
# 61/61 [==============================] - 26s 421ms/step - loss: 0.5424 - accuracy: 0.7875 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 43/50
# 61/61 [==============================] - 26s 421ms/step - loss: 0.5425 - accuracy: 0.7821 - val_loss: 0.7257 - val_accuracy: 0.7042
# Epoch 44/50
# 61/61 [==============================] - 26s 420ms/step - loss: 0.5413 - accuracy: 0.7878 - val_loss: 0.7257 - val_accuracy: 0.7063
# Epoch 45/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5409 - accuracy: 0.7844 - val_loss: 0.7256 - val_accuracy: 0.7042
# Epoch 46/50
# 61/61 [==============================] - 26s 421ms/step - loss: 0.5417 - accuracy: 0.7857 - val_loss: 0.7258 - val_accuracy: 0.7032
# Epoch 47/50
# 61/61 [==============================] - 26s 424ms/step - loss: 0.5392 - accuracy: 0.7870 - val_loss: 0.7258 - val_accuracy: 0.7032
# Epoch 48/50
# 61/61 [==============================] - 26s 421ms/step - loss: 0.5400 - accuracy: 0.7873 - val_loss: 0.7256 - val_accuracy: 0.7032
# Epoch 49/50
# 61/61 [==============================] - 26s 425ms/step - loss: 0.5422 - accuracy: 0.7875 - val_loss: 0.7255 - val_accuracy: 0.7053
# Epoch 50/50
# 61/61 [==============================] - 26s 423ms/step - loss: 0.5450 - accuracy: 0.7865 - val_loss: 0.7256 - val_accuracy: 0.7053

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy: 2 sigma set')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('InceptionNet200_macc_2sig.png')
plt.show()

# %%
#current verdict? it does quite well on the 2d5 thing... much better than i imagined. Not so much for the 2d0 thing... but maybe that lightcurve needs 
#rebinning... and  i havent fine tuned it or anything yet.
test_loss, test_acc = NN.evaluate(np.array(Xtest), np.array(Ytest))
print('Test accuracy:', test_acc)
Ypred_raw=NN.predict(np.array(Xtest))
Ypred=np.argmax(Ypred_raw, axis=1)
Ytest_new=np.argmax(Ytest,axis=1)
cm = confusion_matrix(Ytest_new, Ypred)
print(cm)
# Out:
# 38/38 [==============================] - 2s 45ms/step - loss: 0.8014 - accuracy: 0.7061
# Test accuracy: 0.7061258554458618
# [[263 107  11]
#  [108 273  29]
#  [ 52  48 317]]
