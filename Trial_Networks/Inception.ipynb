# %%
#here's my attempt at writing a different NN to tackle my problem... this is an inception network. lets see if it works
import numpy as np
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from tensorflow.keras import layers
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix

# %%
IMG_SIZE=500

# %%
#some errors in this class thing so we'll see later....
class InceptionTime(keras.layers.Layer):
    def __init__(self, num_filters=32, activation='relu', **kwargs):
        super().__init__(**kwargs)
        self.num_filters=num_filters
        self.activation=keras.activations.get(activation)
        #self.conv1=keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")
        #self.conv1_2=keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")
        #self.conv10=keras.layers.Conv1D(filters=8, kernel_size=10, padding="same", strides=1, activation="tanh")
        #self.conv20=keras.layers.Conv1D(filters=8, kernel_size=20, padding="same", strides=1, activation="tanh")
        #self.conv40=keras.layers.Conv1D(filters=8, kernel_size=40, padding="same", strides=1, activation="tanh")

    def call(self, inputs,training=None):
        bN = keras.layers.Conv1D(filters=self.num_filters, kernel_size=1, padding="same", strides=1, activation="tanh")(inputs)
        mP = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(inputs)
        z1 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=3, padding="same", strides=1, activation="tanh")(bN)
        z2 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=7, padding="same", strides=1, activation="tanh")(bN)
        z3 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=11, padding="same", strides=1, activation="tanh")(bN)
        z4 = keras.layers.Conv1D(filters=self.num_filters, kernel_size=1, padding="same", strides=1, activation="tanh")(mP)
        z = keras.layers.Concatenate(axis=2)([z1,z2,z3,z4])
        z = keras.layers.BatchNormalization()(z)
        return self.activation(z)

# %%
ip = keras.layers.Input(shape=(IMG_SIZE,1),name='Input')
x = keras.layers.Reshape((IMG_SIZE, 1), input_shape=(IMG_SIZE,),name='reshape_1')(ip)
x = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same", strides=1, activation="tanh")(x)

y = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=2, activation="tanh",name='bypass')(x)
y = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=2, activation="relu",name='bypass2')(y)
y = keras.layers.BatchNormalization()(y)

bN1 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(x)
bN2 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(x)
bN3 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(x)
mP = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(x)
z1 = keras.layers.Conv1D(filters=8, kernel_size=5, padding="same", strides=1, activation="tanh")(bN1)
z2 = keras.layers.Conv1D(filters=8, kernel_size=15, padding="same", strides=1, activation="tanh")(bN2)
z3 = keras.layers.Conv1D(filters=8, kernel_size=35, padding="same", strides=1, activation="tanh")(bN3)
z4 = keras.layers.Conv1D(filters=4, kernel_size=1, padding="same", strides=1, activation="tanh")(mP)
z = keras.layers.Concatenate(axis=2)([z1,z2,z3,z4])
z = keras.layers.BatchNormalization()(z)

z  = keras.layers.AveragePooling1D(3,strides=2,padding='same')(z)

bNI1 = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(z)
bNI2 = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(z)
bNI3 = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(z)
mPI = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(z)
zI1 = keras.layers.Conv1D(filters=16, kernel_size=5, padding="same", strides=1, activation="tanh")(bNI1)
zI2 = keras.layers.Conv1D(filters=16, kernel_size=15, padding="same", strides=1, activation="tanh")(bNI2)
zI3 = keras.layers.Conv1D(filters=16, kernel_size=35, padding="same", strides=1, activation="tanh")(bNI3)
zI4 = keras.layers.Conv1D(filters=8, kernel_size=1, padding="same", strides=1, activation="tanh")(mPI)
zI = keras.layers.Concatenate(axis=2)([zI1,zI2,zI3,zI4])
zI = keras.layers.BatchNormalization()(zI)

zI  = keras.layers.AveragePooling1D(3,strides=2,padding='same')(zI)

bNII1 = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=1, activation="tanh")(zI)
bNII2 = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=1, activation="tanh")(zI)
bNII3 = keras.layers.Conv1D(filters=32, kernel_size=1, padding="same", strides=1, activation="tanh")(zI)
mPII = keras.layers.MaxPool1D(3,strides=1 ,data_format='channels_last',padding='same')(zI)
z1II = keras.layers.Conv1D(filters=32, kernel_size=5, padding="same", strides=1, activation="tanh")(bNII1)
z2II = keras.layers.Conv1D(filters=32, kernel_size=15, padding="same", strides=1, activation="tanh")(bNII2)
z3II = keras.layers.Conv1D(filters=32, kernel_size=35, padding="same", strides=1, activation="tanh")(bNII3)
z4II = keras.layers.Conv1D(filters=16, kernel_size=1, padding="same", strides=1, activation="tanh")(mPII)
zII = keras.layers.Concatenate(axis=2,name='bypassed_here')([z1II,z2II,z3II,z4II,y])
zII = keras.layers.BatchNormalization()(zII)

zII  = keras.layers.AveragePooling1D(3,strides=1,padding='same')(zII)

zII = keras.layers.Flatten()(zII)
zII = keras.layers.Dense(128,activation='relu')(zII)
zII = keras.layers.Dense(64,activation='relu')(zII)
#zII =  keras.layers.Dense(1,activation='relu')(zII)
zII =  keras.layers.Dense(2,activation='softmax')(zII)

NN = keras.Model(inputs=ip, outputs=zII ,name='Convolutional_NN')
NN.summary()


lr_schedule = keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=0.00005,decay_steps=500,decay_rate=0.5)
NN.compile(optimizer=keras.optimizers.Adam(learning_rate=lr_schedule), loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# Model: "Convolutional_NN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# Input (InputLayer)              [(None, 500, 1)]     0
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 500, 1)       0           Input[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 500, 64)      256         reshape_1[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 500, 8)       520         conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 500, 8)       520         conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 500, 8)       520         conv1d_22[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 500, 64)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 500, 8)       328         conv1d_23[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 500, 8)       968         conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 500, 8)       2248        conv1d_25[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 500, 4)       260         max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 500, 28)      0           conv1d_26[0][0]
#                                                                  conv1d_27[0][0]
#                                                                  conv1d_28[0][0]
#                                                                  conv1d_29[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 500, 28)      112         concatenate_2[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_3 (AveragePoo (None, 250, 28)      0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 250, 16)      464         average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 250, 16)      464         average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 250, 16)      464         average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 250, 28)      0           average_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 250, 16)      1296        conv1d_30[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 250, 16)      3856        conv1d_31[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 250, 16)      8976        conv1d_32[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 250, 8)       232         max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 250, 56)      0           conv1d_33[0][0]
#                                                                  conv1d_34[0][0]
#                                                                  conv1d_35[0][0]
#                                                                  conv1d_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 250, 56)      224         concatenate_3[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_4 (AveragePoo (None, 125, 56)      0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# bypass (Conv1D)                 (None, 250, 32)      2080        conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 125, 32)      1824        average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 125, 32)      1824        average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 125, 32)      1824        average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 125, 56)      0           average_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# bypass2 (Conv1D)                (None, 125, 32)      1056        bypass[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 125, 32)      5152        conv1d_37[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 125, 32)      15392       conv1d_38[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 125, 32)      35872       conv1d_39[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 125, 16)      912         max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 125, 32)      128         bypass2[0][0]
# __________________________________________________________________________________________________
# bypassed_here (Concatenate)     (None, 125, 144)     0           conv1d_40[0][0]
#                                                                  conv1d_41[0][0]
#                                                                  conv1d_42[0][0]
#                                                                  conv1d_43[0][0]
#                                                                  batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 125, 144)     576         bypassed_here[0][0]
# __________________________________________________________________________________________________
# average_pooling1d_5 (AveragePoo (None, 125, 144)     0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 18000)        0           average_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          2304128     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           8256        dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            130         dense_4[0][0]
# ==================================================================================================
# Total params: 2,400,862
# Trainable params: 2,400,342
# Non-trainable params: 520
# __________________________________________________________________________________________________

# %%
# np.random.seed(123467)
X_train=np.loadtxt('../../training_data/Xtrain_av_raw500_2_2d0_v2.csv',delimiter=',')
Y_train=np.loadtxt('../../training_data/Ytrain_av_raw500_2_2d0_v2.csv',delimiter=',')
print(X_train.shape,Y_train.shape)
kernel_size = 3
kernel = np.ones(kernel_size) / kernel_size
X_train = np.array([np.convolve(X_train[i], kernel, mode='same') for i in range(len(X_train))])
#X_train=preprocessing.normalize(X_train)
#X_train=-X_train
#scalar=preprocessing.StandardScaler()
#scalar.fit(X_train)
#X_train=scalar.transform(X_train)

Xtrain, Xtest, Ytrain, Ytest = train_test_split(X_train, Y_train, test_size=0.2)
print(Xtrain.shape,Xtest.shape)

vararr=np.random.randint(0,len(Xtrain),size=10)
fig,ax=plt.subplots(10,1,figsize=(10,20))
for i in range(0,10):
    ax[i].plot(Xtrain[vararr[i]])

plt.show
# Out:
# (9598, 500) (9598, 2)
# (7678, 500) (1920, 500)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
es_callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)
#history=convNN.fit([np.array(Xtrain),np.array(Xtrainl)],np.array(Ytrain), batch_size=64, epochs=40, verbose=VERBOSE, validation_split=0.12,callbacks=[es_callback])
history=NN.fit(np.array(Xtrain),np.array(Ytrain), batch_size=64, epochs=50  , verbose=1 ,shuffle=True, validation_split=0.2)
# Out:
# Epoch 1/50
# 96/96 [==============================] - 18s 192ms/step - loss: 0.4257 - accuracy: 0.8048 - val_loss: 0.5578 - val_accuracy: 0.7116
# Epoch 2/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4246 - accuracy: 0.8020 - val_loss: 0.5583 - val_accuracy: 0.7103
# Epoch 3/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4257 - accuracy: 0.8030 - val_loss: 0.5580 - val_accuracy: 0.7129
# Epoch 4/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4242 - accuracy: 0.8043 - val_loss: 0.5584 - val_accuracy: 0.7116
# Epoch 5/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4237 - accuracy: 0.8020 - val_loss: 0.5582 - val_accuracy: 0.7129
# Epoch 6/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4248 - accuracy: 0.8061 - val_loss: 0.5579 - val_accuracy: 0.7116
# Epoch 7/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.4246 - accuracy: 0.8046 - val_loss: 0.5583 - val_accuracy: 0.7116
# Epoch 8/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4264 - accuracy: 0.8041 - val_loss: 0.5583 - val_accuracy: 0.7122
# Epoch 9/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4252 - accuracy: 0.8033 - val_loss: 0.5584 - val_accuracy: 0.7129
# Epoch 10/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4248 - accuracy: 0.8041 - val_loss: 0.5585 - val_accuracy: 0.7122
# Epoch 11/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4251 - accuracy: 0.8093 - val_loss: 0.5581 - val_accuracy: 0.7129
# Epoch 12/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4253 - accuracy: 0.8059 - val_loss: 0.5583 - val_accuracy: 0.7129
# Epoch 13/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4258 - accuracy: 0.8025 - val_loss: 0.5582 - val_accuracy: 0.71090.4251 - accuracy:  - ETA: 0s - loss: 0.4264 - accuracy:
# Epoch 14/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4239 - accuracy: 0.8079 - val_loss: 0.5585 - val_accuracy: 0.7116
# Epoch 15/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4241 - accuracy: 0.8056 - val_loss: 0.5585 - val_accuracy: 0.7129
# Epoch 16/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4234 - accuracy: 0.8033 - val_loss: 0.5585 - val_accuracy: 0.7135
# Epoch 17/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4257 - accuracy: 0.8036 - val_loss: 0.5585 - val_accuracy: 0.7129
# Epoch 18/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4245 - accuracy: 0.8035 - val_loss: 0.5584 - val_accuracy: 0.7122
# Epoch 19/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4247 - accuracy: 0.8064 - val_loss: 0.5588 - val_accuracy: 0.7142
# Epoch 20/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4246 - accuracy: 0.8061 - val_loss: 0.5585 - val_accuracy: 0.7129
# Epoch 21/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4236 - accuracy: 0.8046 - val_loss: 0.5586 - val_accuracy: 0.7135
# Epoch 22/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4249 - accuracy: 0.8053 - val_loss: 0.5584 - val_accuracy: 0.7142
# Epoch 23/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4247 - accuracy: 0.8045 - val_loss: 0.5584 - val_accuracy: 0.7142
# Epoch 24/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4273 - accuracy: 0.8053 - val_loss: 0.5587 - val_accuracy: 0.7142
# Epoch 25/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4267 - accuracy: 0.8046 - val_loss: 0.5586 - val_accuracy: 0.7122
# Epoch 26/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4256 - accuracy: 0.8048 - val_loss: 0.5582 - val_accuracy: 0.7116
# Epoch 27/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4273 - accuracy: 0.8032 - val_loss: 0.5587 - val_accuracy: 0.7122
# Epoch 28/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4248 - accuracy: 0.8059 - val_loss: 0.5583 - val_accuracy: 0.7129
# Epoch 29/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4253 - accuracy: 0.8046 - val_loss: 0.5579 - val_accuracy: 0.7129
# Epoch 30/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4255 - accuracy: 0.8080 - val_loss: 0.5578 - val_accuracy: 0.7129
# Epoch 31/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4250 - accuracy: 0.8046 - val_loss: 0.5578 - val_accuracy: 0.7129
# Epoch 32/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4240 - accuracy: 0.8059 - val_loss: 0.5589 - val_accuracy: 0.7135
# Epoch 33/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4251 - accuracy: 0.8064 - val_loss: 0.5585 - val_accuracy: 0.7135
# Epoch 34/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.4250 - accuracy: 0.8025 - val_loss: 0.5586 - val_accuracy: 0.7122
# Epoch 35/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.4239 - accuracy: 0.8054 - val_loss: 0.5586 - val_accuracy: 0.7135
# Epoch 36/50
# 96/96 [==============================] - 18s 191ms/step - loss: 0.4251 - accuracy: 0.8069 - val_loss: 0.5582 - val_accuracy: 0.7116
# Epoch 37/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4252 - accuracy: 0.8054 - val_loss: 0.5581 - val_accuracy: 0.7129
# Epoch 38/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.4248 - accuracy: 0.8049 - val_loss: 0.5584 - val_accuracy: 0.7122
# Epoch 39/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4244 - accuracy: 0.8074 - val_loss: 0.5584 - val_accuracy: 0.7135
# Epoch 40/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4218 - accuracy: 0.8048 - val_loss: 0.5580 - val_accuracy: 0.7129
# Epoch 41/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.4238 - accuracy: 0.8059 - val_loss: 0.5582 - val_accuracy: 0.7122
# Epoch 42/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4249 - accuracy: 0.8017 - val_loss: 0.5582 - val_accuracy: 0.7122
# Epoch 43/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4255 - accuracy: 0.8028 - val_loss: 0.5583 - val_accuracy: 0.7129
# Epoch 44/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4282 - accuracy: 0.8017 - val_loss: 0.5584 - val_accuracy: 0.7135
# Epoch 45/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4256 - accuracy: 0.8040 - val_loss: 0.5586 - val_accuracy: 0.7142
# Epoch 46/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4249 - accuracy: 0.8074 - val_loss: 0.5586 - val_accuracy: 0.7129
# Epoch 47/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4257 - accuracy: 0.8014 - val_loss: 0.5586 - val_accuracy: 0.7129
# Epoch 48/50
# 96/96 [==============================] - 18s 189ms/step - loss: 0.4254 - accuracy: 0.8051 - val_loss: 0.5585 - val_accuracy: 0.7129
# Epoch 49/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4244 - accuracy: 0.8074 - val_loss: 0.5582 - val_accuracy: 0.7129
# Epoch 50/50
# 96/96 [==============================] - 18s 190ms/step - loss: 0.4254 - accuracy: 0.8040 - val_loss: 0.5581 - val_accuracy: 0.7142

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy: 2 sigma set')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.savefig('InceptionNet200_macc_2sig.png')
plt.show()

# %%
#current verdict? it does quite well on the 2d5 thing... much better than i imagined. Not so much for the 2d0 thing... but maybe that lightcurve needs 
#rebinning... and  i havent fine tuned it or anything yet.
test_loss, test_acc = NN.evaluate(np.array(Xtest), np.array(Ytest))
print('Test accuracy:', test_acc)
Ypred_raw=NN.predict(np.array(Xtest))
Ypred=np.argmax(Ypred_raw, axis=1)
Ytest_new=np.argmax(Ytest,axis=1)
cm = confusion_matrix(Ytest_new, Ypred)
print(cm/cm.sum())
# Out:
# 60/60 [==============================] - 2s 37ms/step - loss: 0.5520 - accuracy: 0.7193
# Test accuracy: 0.7192708253860474
# [[0.37447917 0.12916667]
#  [0.1515625  0.34479167]]
