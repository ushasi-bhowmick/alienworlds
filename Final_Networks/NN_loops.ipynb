# %%
#attempt to improve the NN
#add the local and the global view construct coz transit false positive mismatch seems to be a major problem
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

# %%
temp1=np.loadtxt('training_data/Xtrain_av_raw.csv',delimiter=',')
temp2=np.loadtxt('training_data/Xtrain_av_raw_v2.csv',delimiter=',')
temp3=np.loadtxt('training_data/Xtrain_av_raw_v3.csv',delimiter=',')
temp4=np.loadtxt('training_data/Xtrain_av_raw_v4.csv',delimiter=',')
print(temp1.shape)
print(temp2.shape)
print(temp3.shape)
print(temp4.shape)
# Out:
# (4700, 2000)
# (6710, 200)
# (6710, 100)
# (6636, 200)

# %%
acc_func=[]
val_acc_func=[]
test_accuracy=[]

# %%
#main code:
#Q1. ARE MORE LAYERS BETTER? We use 2 classifier Training sample to test this
def are_more_layers_better(Xtrain,Ytrain,Xtest,Ytest,img_size,no_l,epoch):
    #add hidden layers
    conv_ip = keras.layers.Input(shape=(img_size,),name='Input')
    x=keras.layers.Reshape((img_size, 1), input_shape=(img_size,),name='reshape_1')(conv_ip)
    x=keras.layers.BatchNormalization()(x)

    for i in range(0,no_l):
        x=keras.layers.Conv1D(16,kernel_size=3,strides=1,activation='tanh',name='conv16_3_'+str(i))(x)
    x=keras.layers.MaxPool1D(3,strides=2 ,data_format='channels_last',name='maxpool_1')(x)
    for i in range(0,no_l):
        x=keras.layers.Conv1D(32,kernel_size=3,strides=1,activation='tanh',name='conv32_3_'+str(i))(x)
    x=keras.layers.MaxPool1D(3,strides=2,data_format='channels_last',name='maxpool_2')(x)
    x=keras.layers.Flatten(name='flat_1')(x)
    x3=keras.layers.Dense(128,name='dense_layer_1',activation='relu')(x)
    x3=keras.layers.Dense(128,name='dense_layer_3',activation='relu')(x3)
    conv_op=keras.layers.Dense(2,name='dense_layer_4',activation='softmax')(x3)

    convNN = keras.Model(inputs=conv_ip, outputs=conv_op,name='Convolutional_NN')
    convNN.summary()
    convNN.compile(optimizer=keras.optimizers.Adam(learning_rate=0.00005), loss='categorical_crossentropy',metrics=['accuracy'])
    es_callback = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)
    history=convNN.fit(np.array(Xtrain),np.array(Ytrain), batch_size=64, epochs=epoch , verbose=1 , validation_split=0.2,callbacks=[es_callback])

    fig,ax=plt.subplots(1,1,figsize=(5,5))
    ax.plot(history.history['accuracy'])
    ax.plot(history.history['val_accuracy'])
    ax.set_title('model Accuracy')
    ax.set_ylabel('Accuracy')
    ax.set_xlabel('epoch')
    ax.legend(['train', 'test'], loc='upper left')
    plt.savefig('loop_acc_100_3d0'+str(no_l)+'_'+str(img_size)+'.png')

    test_loss, test_acc = convNN.evaluate(np.array(Xtest), np.array(Ytest))
    print('Test accuracy:', test_acc)
    test_accuracy.append(test_acc)
    acc_func.append(history.history['accuracy'])
    val_acc_func.append(history.history['val_accuracy'])
    #plt.show()

# %%
X_train=np.loadtxt('training_data/Xtrain_av_raw200_2_3d0.csv',delimiter=',')
Y_train=np.loadtxt('training_data/Ytrain_av_raw200_2_3d0.csv',delimiter=',')
Xtrain, Xtest, Ytrain, Ytest = train_test_split(X_train, Y_train, test_size=0.1)

Xtrain=Xtrain[:,50:150]
Xtest=Xtest[:,50:150]
print("shapes:",Xtrain.shape,Ytrain.shape,Xtest.shape,Ytest.shape)
# Out:
# shapes: (1161, 100) (1161, 2) (129, 100) (129, 2)

# %%
are_more_layers_better(Xtrain,Ytrain,Xtest,Ytest,100,1,100)
are_more_layers_better(Xtrain,Ytrain,Xtest,Ytest,100,2,100)
are_more_layers_better(Xtrain,Ytrain,Xtest,Ytest,100,3,100)
are_more_layers_better(Xtrain,Ytrain,Xtest,Ytest,100,4,100)
are_more_layers_better(Xtrain,Ytrain,Xtest,Ytest,100,5,100)
# Out:
# Model: "Convolutional_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 100)]             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 100, 1)            0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 100, 1)            4
# _________________________________________________________________
# conv16_3_0 (Conv1D)          (None, 98, 16)            64
# _________________________________________________________________
# maxpool_1 (MaxPooling1D)     (None, 48, 16)            0
# _________________________________________________________________
# conv32_3_0 (Conv1D)          (None, 46, 32)            1568
# _________________________________________________________________
# maxpool_2 (MaxPooling1D)     (None, 22, 32)            0
# _________________________________________________________________
# flat_1 (Flatten)             (None, 704)               0
# _________________________________________________________________
# dense_layer_1 (Dense)        (None, 128)               90240
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dense_layer_4 (Dense)        (None, 2)                 258
# =================================================================
# Total params: 108,646
# Trainable params: 108,644
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/100
# 15/15 [==============================] - 2s 38ms/step - loss: 0.6468 - accuracy: 0.7812 - val_loss: 0.6861 - val_accuracy: 0.4678
# Epoch 2/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5971 - accuracy: 0.8028 - val_loss: 0.6802 - val_accuracy: 0.4678
# Epoch 3/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5565 - accuracy: 0.8211 - val_loss: 0.6722 - val_accuracy: 0.8155
# Epoch 4/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.5226 - accuracy: 0.8179 - val_loss: 0.6625 - val_accuracy: 0.8283
# Epoch 5/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4910 - accuracy: 0.8319 - val_loss: 0.6515 - val_accuracy: 0.7940
# Epoch 6/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4711 - accuracy: 0.8222 - val_loss: 0.6394 - val_accuracy: 0.7897
# Epoch 7/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4480 - accuracy: 0.8405 - val_loss: 0.6266 - val_accuracy: 0.7768
# Epoch 8/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4320 - accuracy: 0.8341 - val_loss: 0.6152 - val_accuracy: 0.7768
# Epoch 9/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4268 - accuracy: 0.8254 - val_loss: 0.6040 - val_accuracy: 0.7768
# Epoch 10/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4183 - accuracy: 0.8254 - val_loss: 0.5939 - val_accuracy: 0.7897
# Epoch 11/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4125 - accuracy: 0.8179 - val_loss: 0.5831 - val_accuracy: 0.7897
# Epoch 12/100
# 15/15 [==============================] - 0s 15ms/step - loss: 0.3994 - accuracy: 0.8308 - val_loss: 0.5753 - val_accuracy: 0.7897
# Epoch 13/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3959 - accuracy: 0.8319 - val_loss: 0.5679 - val_accuracy: 0.7940
# Epoch 14/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.3981 - accuracy: 0.8244 - val_loss: 0.5625 - val_accuracy: 0.8112
# Epoch 15/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3883 - accuracy: 0.8384 - val_loss: 0.5513 - val_accuracy: 0.7983
# Epoch 16/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3902 - accuracy: 0.8330 - val_loss: 0.5470 - val_accuracy: 0.8197
# Epoch 17/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3871 - accuracy: 0.8341 - val_loss: 0.5413 - val_accuracy: 0.8240
# Epoch 18/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3860 - accuracy: 0.8319 - val_loss: 0.5344 - val_accuracy: 0.8240
# Epoch 19/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.3863 - accuracy: 0.8265 - val_loss: 0.5281 - val_accuracy: 0.8240
# Epoch 20/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.3822 - accuracy: 0.8341 - val_loss: 0.5278 - val_accuracy: 0.8283
# Epoch 21/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3775 - accuracy: 0.8297 - val_loss: 0.5152 - val_accuracy: 0.8240
# Epoch 22/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3795 - accuracy: 0.8373 - val_loss: 0.5115 - val_accuracy: 0.8326
# Epoch 23/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3834 - accuracy: 0.8297 - val_loss: 0.5076 - val_accuracy: 0.8326
# Epoch 24/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3772 - accuracy: 0.8287 - val_loss: 0.4970 - val_accuracy: 0.8240
# Epoch 25/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3782 - accuracy: 0.8384 - val_loss: 0.4937 - val_accuracy: 0.8369
# Epoch 26/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3762 - accuracy: 0.8394 - val_loss: 0.4880 - val_accuracy: 0.8369
# Epoch 27/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3767 - accuracy: 0.8438 - val_loss: 0.4810 - val_accuracy: 0.8283
# Epoch 28/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3724 - accuracy: 0.8416 - val_loss: 0.4789 - val_accuracy: 0.8326
# Epoch 29/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3746 - accuracy: 0.8384 - val_loss: 0.4668 - val_accuracy: 0.8240
# Epoch 30/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3659 - accuracy: 0.8373 - val_loss: 0.4657 - val_accuracy: 0.8326
# Epoch 31/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3666 - accuracy: 0.8362 - val_loss: 0.4620 - val_accuracy: 0.8412
# Epoch 32/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3746 - accuracy: 0.8394 - val_loss: 0.4519 - val_accuracy: 0.8326
# Epoch 33/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3670 - accuracy: 0.8362 - val_loss: 0.4545 - val_accuracy: 0.8455
# Epoch 34/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3656 - accuracy: 0.8394 - val_loss: 0.4411 - val_accuracy: 0.8283
# Epoch 35/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3695 - accuracy: 0.8341 - val_loss: 0.4432 - val_accuracy: 0.8412
# Epoch 36/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3673 - accuracy: 0.8427 - val_loss: 0.4390 - val_accuracy: 0.8412
# Epoch 37/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3604 - accuracy: 0.8416 - val_loss: 0.4304 - val_accuracy: 0.8369
# Epoch 38/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3600 - accuracy: 0.8405 - val_loss: 0.4287 - val_accuracy: 0.8412
# Epoch 39/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3608 - accuracy: 0.8416 - val_loss: 0.4266 - val_accuracy: 0.8498
# Epoch 40/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3582 - accuracy: 0.8513 - val_loss: 0.4260 - val_accuracy: 0.8498
# Epoch 41/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3637 - accuracy: 0.8448 - val_loss: 0.4180 - val_accuracy: 0.8455
# Epoch 42/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3661 - accuracy: 0.8384 - val_loss: 0.4174 - val_accuracy: 0.8498
# Epoch 43/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3592 - accuracy: 0.8448 - val_loss: 0.4161 - val_accuracy: 0.8498
# Epoch 44/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3579 - accuracy: 0.8491 - val_loss: 0.4129 - val_accuracy: 0.8498
# Epoch 45/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3484 - accuracy: 0.8513 - val_loss: 0.4085 - val_accuracy: 0.8455
# Epoch 46/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3630 - accuracy: 0.8384 - val_loss: 0.4072 - val_accuracy: 0.8455
# Epoch 47/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3601 - accuracy: 0.8394 - val_loss: 0.4060 - val_accuracy: 0.8455
# Epoch 48/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3519 - accuracy: 0.8470 - val_loss: 0.4054 - val_accuracy: 0.8498
# Epoch 49/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3538 - accuracy: 0.8534 - val_loss: 0.4020 - val_accuracy: 0.8455
# Epoch 50/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3519 - accuracy: 0.8545 - val_loss: 0.4020 - val_accuracy: 0.8498
# Epoch 51/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3616 - accuracy: 0.8470 - val_loss: 0.4011 - val_accuracy: 0.8498
# Epoch 52/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3578 - accuracy: 0.8405 - val_loss: 0.3981 - val_accuracy: 0.8412
# Epoch 53/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3564 - accuracy: 0.8470 - val_loss: 0.3990 - val_accuracy: 0.8541
# Epoch 54/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3468 - accuracy: 0.8610 - val_loss: 0.3967 - val_accuracy: 0.8498
# Epoch 55/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3550 - accuracy: 0.8470 - val_loss: 0.3952 - val_accuracy: 0.8498
# Epoch 56/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3507 - accuracy: 0.8470 - val_loss: 0.3952 - val_accuracy: 0.8541
# Epoch 57/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3502 - accuracy: 0.8491 - val_loss: 0.3938 - val_accuracy: 0.8541
# Epoch 58/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3517 - accuracy: 0.8502 - val_loss: 0.3930 - val_accuracy: 0.8541
# Epoch 59/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3485 - accuracy: 0.8481 - val_loss: 0.3915 - val_accuracy: 0.8498
# Epoch 60/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3536 - accuracy: 0.8384 - val_loss: 0.3906 - val_accuracy: 0.8541
# Epoch 61/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3404 - accuracy: 0.8513 - val_loss: 0.3900 - val_accuracy: 0.8541
# Epoch 62/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3458 - accuracy: 0.8448 - val_loss: 0.3890 - val_accuracy: 0.8541
# Epoch 63/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3436 - accuracy: 0.8524 - val_loss: 0.3885 - val_accuracy: 0.8541
# Epoch 64/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3404 - accuracy: 0.8534 - val_loss: 0.3878 - val_accuracy: 0.8541
# Epoch 65/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3369 - accuracy: 0.8578 - val_loss: 0.3868 - val_accuracy: 0.8541
# Epoch 66/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3484 - accuracy: 0.8470 - val_loss: 0.3857 - val_accuracy: 0.8541
# Epoch 67/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3350 - accuracy: 0.8610 - val_loss: 0.3854 - val_accuracy: 0.8541
# Epoch 68/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3404 - accuracy: 0.8470 - val_loss: 0.3850 - val_accuracy: 0.8541
# Epoch 69/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.3378 - accuracy: 0.8556 - val_loss: 0.3838 - val_accuracy: 0.8541
# Epoch 70/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3372 - accuracy: 0.8588 - val_loss: 0.3819 - val_accuracy: 0.8541
# Epoch 71/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3324 - accuracy: 0.8610 - val_loss: 0.3824 - val_accuracy: 0.8541
# Epoch 72/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3470 - accuracy: 0.8481 - val_loss: 0.3801 - val_accuracy: 0.8541
# Epoch 73/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3415 - accuracy: 0.8567 - val_loss: 0.3801 - val_accuracy: 0.8584
# Epoch 74/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3375 - accuracy: 0.8556 - val_loss: 0.3796 - val_accuracy: 0.8541
# Epoch 75/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3321 - accuracy: 0.8631 - val_loss: 0.3786 - val_accuracy: 0.8541
# Epoch 76/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3290 - accuracy: 0.8675 - val_loss: 0.3785 - val_accuracy: 0.8541
# Epoch 77/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3313 - accuracy: 0.8664 - val_loss: 0.3773 - val_accuracy: 0.8498
# Epoch 78/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3346 - accuracy: 0.8556 - val_loss: 0.3769 - val_accuracy: 0.8541
# Epoch 79/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3279 - accuracy: 0.8513 - val_loss: 0.3763 - val_accuracy: 0.8541
# Epoch 80/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3431 - accuracy: 0.8545 - val_loss: 0.3753 - val_accuracy: 0.8541
# Epoch 81/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3292 - accuracy: 0.8642 - val_loss: 0.3761 - val_accuracy: 0.8541
# Epoch 82/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3329 - accuracy: 0.8578 - val_loss: 0.3743 - val_accuracy: 0.8541
# Epoch 83/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3352 - accuracy: 0.8556 - val_loss: 0.3747 - val_accuracy: 0.8541
# Epoch 84/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3201 - accuracy: 0.8621 - val_loss: 0.3736 - val_accuracy: 0.8541
# Epoch 85/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3283 - accuracy: 0.8642 - val_loss: 0.3737 - val_accuracy: 0.8541
# Epoch 86/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3254 - accuracy: 0.8653 - val_loss: 0.3718 - val_accuracy: 0.8541
# Epoch 87/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.3242 - accuracy: 0.8642 - val_loss: 0.3731 - val_accuracy: 0.8541
# Epoch 88/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.3221 - accuracy: 0.8642 - val_loss: 0.3709 - val_accuracy: 0.8541
# Epoch 89/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3197 - accuracy: 0.8675 - val_loss: 0.3702 - val_accuracy: 0.8541
# Epoch 90/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3285 - accuracy: 0.8610 - val_loss: 0.3705 - val_accuracy: 0.8541
# Epoch 91/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3285 - accuracy: 0.8588 - val_loss: 0.3684 - val_accuracy: 0.8584
# Epoch 92/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3288 - accuracy: 0.8610 - val_loss: 0.3687 - val_accuracy: 0.8541
# Epoch 93/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3358 - accuracy: 0.8567 - val_loss: 0.3682 - val_accuracy: 0.8584
# Epoch 94/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3308 - accuracy: 0.8524 - val_loss: 0.3657 - val_accuracy: 0.8541
# Epoch 95/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3230 - accuracy: 0.8642 - val_loss: 0.3641 - val_accuracy: 0.8584
# Epoch 96/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3363 - accuracy: 0.8481 - val_loss: 0.3655 - val_accuracy: 0.8584
# Epoch 97/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3197 - accuracy: 0.8631 - val_loss: 0.3647 - val_accuracy: 0.8584
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3125 - accuracy: 0.8621 - val_loss: 0.3664 - val_accuracy: 0.8541
# Epoch 99/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3296 - accuracy: 0.8556 - val_loss: 0.3632 - val_accuracy: 0.8541
# Epoch 100/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.3203 - accuracy: 0.8653 - val_loss: 0.3644 - val_accuracy: 0.8584
# 5/5 [==============================] - 0s 0s/step - loss: 0.2830 - accuracy: 0.8915
# Test accuracy: 0.8914728760719299
# Model: "Convolutional_NN"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Input (InputLayer)           [(None, 100)]             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 100, 1)            0
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 100, 1)            4
# _________________________________________________________________
# conv16_3_0 (Conv1D)          (None, 98, 16)            64
# _________________________________________________________________
# conv16_3_1 (Conv1D)          (None, 96, 16)            784
# _________________________________________________________________
# maxpool_1 (MaxPooling1D)     (None, 47, 16)            0
# _________________________________________________________________
# conv32_3_0 (Conv1D)          (None, 45, 32)            1568
# _________________________________________________________________
# conv32_3_1 (Conv1D)          (None, 43, 32)            3104
# _________________________________________________________________
# maxpool_2 (MaxPooling1D)     (None, 21, 32)            0
# _________________________________________________________________
# flat_1 (Flatten)             (None, 672)               0
# _________________________________________________________________
# dense_layer_1 (Dense)        (None, 128)               86144
# _________________________________________________________________
# dense_layer_3 (Dense)        (None, 128)               16512
# _________________________________________________________________
# dense_layer_4 (Dense)        (None, 2)                 258
# =================================================================
# Total params: 108,438
# Trainable params: 108,436
# Non-trainable params: 2
# _________________________________________________________________
# Epoch 1/100
# 15/15 [==============================] - 2s 37ms/step - loss: 0.7145 - accuracy: 0.4828 - val_loss: 0.6928 - val_accuracy: 0.6395
# Epoch 2/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6715 - accuracy: 0.7209 - val_loss: 0.6875 - val_accuracy: 0.7253
# Epoch 3/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.6354 - accuracy: 0.8211 - val_loss: 0.6806 - val_accuracy: 0.7296
# Epoch 4/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.6003 - accuracy: 0.8244 - val_loss: 0.6709 - val_accuracy: 0.7082
# Epoch 5/100
# 11/15 [=====================>........] - ETA: 0s - loss: 0.5677 - accuracy: 0.8068

# %%
#print(test_accuracy)
#print(acc_func)
#print(val_acc_func)
fig2,ax2=plt.subplots(1,1,figsize=(5,5))
ax2.plot(np.arange(1,len(test_accuracy)+1,1),test_accuracy)
ax2.set_xlabel('number of layers')
ax2.set_ylabel('test accuracy')
plt.savefig('test_acc_progression_3d0_100.png')

fig3,ax3=plt.subplots(1,1,figsize=(7,7))
for i in range(0,len(val_acc_func)):
    ax3.plot(acc_func[i],label="train_lay"+str(i+1))
    ax3.plot(val_acc_func[i],label="test_lay"+str(i+1))
ax3.legend()
ax3.set_xlabel('epoch')
ax3.set_ylabel('accuracy')
plt.savefig('lc_cumulative_3d0_100.png')
plt.show()
